# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
x_roll=[0,1,2,3,4]
y_marks=[100,89,83,92,99]

# %%
subject=["English", "maths", "science", "sst" , "hindi"]
students=[10,14,12,9,5]

# %%
name=["Sourabh" , "Mukul", "abhishek","yash"]
pizza=[10,20,30,50]

# %%
a=[2,3,5,1,6]
b=[4,1,2,5,6]

# %%
plt.figure()

plt.subplot(2,2,1)
plt.grid()
plt.plot(y_marks,color="blue" , marker="*" , label="lololol")
plt.legend()
plt.xlabel("Roll no")
plt.ylabel("Marks")
plt.tight_layout()


plt.subplot(2,2,2)
plt.grid()
plt.xlabel("Name")
plt.ylabel("Pizza")
plt.scatter(name,pizza,marker="*")
plt.tight_layout()

plt.subplot(2,2,3)
plt.plot(a)
plt.plot(b)
plt.xlabel("Student")
plt.ylabel("Marks")
plt.grid()
plt.tight_layout()

plt.subplot(2,2,4)
plt.pie(students,labels=subject)
plt.tight_layout()
plt.show()
