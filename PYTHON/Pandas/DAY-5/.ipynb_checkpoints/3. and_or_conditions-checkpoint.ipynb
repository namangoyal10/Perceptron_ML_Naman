# %%
import pandas as pd

# %%
emp=pd.read_csv("employees.csv")

# %%
emp
# Out:
#     First Name  Gender  Start Date Last Login Time  Salary  Bonus %  \
# 0      Douglas    Male  08-06-1993        12.42 PM   97308    6.945
# 1       Thomas    Male   3/31/1996         6.53 AM   61933    4.170
# 2        Maria  Female   4/23/1993        11.17 AM  130590   11.858
# 3        Jerry    Male  03-04-2005         1.00 PM  138705    9.340
# 4        Larry    Male   1/24/1998         4.47 PM  101004    1.389
# ..         ...     ...         ...             ...     ...      ...
# 995      Henry     NaN  11/23/2014         6.09 AM  132483   16.655
# 996    Phillip    Male   1/31/1984         6.30 AM   42392   19.675
# 997    Russell    Male   5/20/2013        12.39 PM   96914    1.421
# 998      Larry    Male   4/20/2013         4.45 PM   60500   11.985
# 999     Albert    Male   5/15/2012         6.24 PM  129949   10.169
#
#     Senior Management                  Team
# 0                True             Marketing
# 1                True                   NaN
# ...

# %% [markdown]
# # AND & conditions

# %%
job_one = emp["Salary"] > 70000
job_two = emp["Bonus %"]>7.00

# %%
emp[job_one & job_two]

## here emp[job_one and job_two] doesnt work
# Out:
#     First Name  Gender  Start Date Last Login Time  Salary  Bonus %  \
# 2        Maria  Female   4/23/1993        11.17 AM  130590   11.858
# 3        Jerry    Male  03-04-2005         1.00 PM  138705    9.340
# 5       Dennis    Male   4/18/1987         1.35 AM  115163   10.125
# 8       Angela  Female  11/22/2005         6.29 AM   95570   18.523
# 9      Frances  Female  08-08-2002         6.51 AM  139852    7.524
# ..         ...     ...         ...             ...     ...      ...
# 990      Robin  Female   7/24/1987         1.35 PM  100765   10.982
# 991       Rose  Female   8/25/2002         5.12 AM  134505   11.051
# 992    Anthony    Male  10/16/2011         8.35 AM  112769   11.625
# 995      Henry     NaN  11/23/2014         6.09 AM  132483   16.655
# 999     Albert    Male   5/15/2012         6.24 PM  129949   10.169
#
#     Senior Management                  Team
# 2               False               Finance
# 3                True               Finance
# ...

# %% [markdown]
# # OR | conditions

# %%
emp[job_one | job_two]

## here emp[job_one and job_two] doesnt work
# Out:
#     First Name  Gender  Start Date Last Login Time  Salary  Bonus %  \
# 0      Douglas    Male  08-06-1993        12.42 PM   97308    6.945
# 2        Maria  Female   4/23/1993        11.17 AM  130590   11.858
# 3        Jerry    Male  03-04-2005         1.00 PM  138705    9.340
# 4        Larry    Male   1/24/1998         4.47 PM  101004    1.389
# 5       Dennis    Male   4/18/1987         1.35 AM  115163   10.125
# ..         ...     ...         ...             ...     ...      ...
# 995      Henry     NaN  11/23/2014         6.09 AM  132483   16.655
# 996    Phillip    Male   1/31/1984         6.30 AM   42392   19.675
# 997    Russell    Male   5/20/2013        12.39 PM   96914    1.421
# 998      Larry    Male   4/20/2013         4.45 PM   60500   11.985
# 999     Albert    Male   5/15/2012         6.24 PM  129949   10.169
#
#     Senior Management                  Team
# 0                True             Marketing
# 2               False               Finance
# ...

# %% [markdown]
# # Some more example

# %%
job_three = emp["Gender"] == "Female"

emp[job_three & (job_one | job_two) ]

# brackets are a must . idk what happens if we dont use them
# Out:
#     First Name  Gender  Start Date Last Login Time  Salary  Bonus %  \
# 2        Maria  Female   4/23/1993        11.17 AM  130590   11.858
# 6         Ruby  Female   8/17/1987         4.20 PM   65476   10.012
# 7          NaN  Female   7/20/2015        10.43 AM   45906   11.598
# 8       Angela  Female  11/22/2005         6.29 AM   95570   18.523
# 9      Frances  Female  08-08-2002         6.51 AM  139852    7.524
# ..         ...     ...         ...             ...     ...      ...
# 987     Gloria  Female  12-08-2014         5.08 AM  136709   10.331
# 988      Alice  Female  10-05-2004         9.34 AM   47638   11.209
# 990      Robin  Female   7/24/1987         1.35 PM  100765   10.982
# 991       Rose  Female   8/25/2002         5.12 AM  134505   11.051
# 993       Tina  Female   5/15/1997         3.53 PM   56450   19.040
#
#     Senior Management                  Team
# 2               False               Finance
# 6                True               Product
# ...

# %%
job_four = emp["Team"] == "Finance" 
job_five= emp["Team"] == "Engineering"
emp[ job_four | job_five ]
# Out:
#     First Name  Gender  Start Date Last Login Time  Salary  Bonus %  \
# 2        Maria  Female   4/23/1993        11.17 AM  130590   11.858
# 3        Jerry    Male  03-04-2005         1.00 PM  138705    9.340
# 7          NaN  Female   7/20/2015        10.43 AM   45906   11.598
# 8       Angela  Female  11/22/2005         6.29 AM   95570   18.523
# 14    Kimberly  Female   1/14/1999         7.13 AM   41426   14.543
# ..         ...     ...         ...             ...     ...      ...
# 984      Maria  Female  10/15/2011         4.53 PM   43455   13.040
# 987     Gloria  Female  12-08-2014         5.08 AM  136709   10.331
# 992    Anthony    Male  10/16/2011         8.35 AM  112769   11.625
# 993       Tina  Female   5/15/1997         3.53 PM   56450   19.040
# 996    Phillip    Male   1/31/1984         6.30 AM   42392   19.675
#
#     Senior Management         Team
# 2               False      Finance
# 3                True      Finance
# 7                 NaN      Finance
# ...

# %%
### job_six = emp["Team"] == "Finance" | "Engineering"
### job_six = emp["Team"] == "Finance" | emp["Team"] == "Engineering"
### emp [job_six]
### job_six itself throws error
