# %%
import pandas as pd
import numpy as np

# %%
google=pd.read_csv("google.csv" ,squeeze=True)
google
# Out:
# 0        50.12
# 1        54.10
# 2        54.65
# 3        52.38
# 4        52.95
#          ...
# 3007    772.88
# 3008    771.07
# 3009    773.18
# 3010    771.61
# 3011    782.22
# Name: Stock Price, Length: 3012, dtype: float64

# %%
print(google.is_unique)
print(google.ndim)
print(google.shape)
print(google.size)
print(google.name)
# Out:
# False
# 1
# (3012,)
# 3012
# Stock Price

# %%
rev=pd.read_csv("revenue.csv" , index_col="Date")
rev
# Out:
#          New York  Los Angeles  Miami
# Date
# 1/1/16        985          122    499
# 1/2/16        738          788    534
# 1/3/16         14           20    933
# 1/4/16        730          904    885
# 1/5/16        114           71    253
# 1/6/16        936          502    497
# 1/7/16        123          996    115
# 1/8/16        935          492    886
# 1/9/16        846          954    823
# 1/10/16        54          285    216

# %%
print(rev.sum(axis=1))
# Out:
# Date
# 1/1/16     1606
# 1/2/16     2060
# 1/3/16      967
# 1/4/16     2519
# 1/5/16      438
# 1/6/16     1935
# 1/7/16     1234
# 1/8/16     2313
# 1/9/16     2623
# 1/10/16     555
# dtype: int64

# %%
print(rev.sum(axis=0))
# Out:
# New York       5475
# Los Angeles    5134
# Miami          5641
# dtype: int64

# %%
print(rev.sum(axis= "index"))
print(rev.sum(axis= "columns"))
# Out:
# New York       5475
# Los Angeles    5134
# Miami          5641
# dtype: int64
# Date
# 1/1/16     1606
# 1/2/16     2060
# 1/3/16      967
# 1/4/16     2519
# 1/5/16      438
# 1/6/16     1935
# 1/7/16     1234
# 1/8/16     2313
# 1/9/16     2623
# 1/10/16     555
# dtype: int64

# %%
nba=pd.read_csv("nba.csv" ,index_col="Number")
nba[["Name", "Age"]].sort_values("Age")
# Out:
#                    Name   Age
# Number
# 1          Devin Booker  19.0
# 20        Rashad Vaughn  19.0
# 34      Cliff Alexander  20.0
# 36         Kevon Looney  20.0
# 0       Emmanuel Mudiay  20.0
# ...                 ...   ...
# 9        Pablo Prigioni  39.0
# 21           Tim Duncan  40.0
# 21        Kevin Garnett  40.0
# 24         Andre Miller  40.0
# 99          Jae Crowder   NaN
#
# [457 rows x 2 columns]

# %%
nba=pd.read_csv("nba.csv")

# %%
nba
# Out:
#               Name            Team  Number Position   Age  Height  Weight  \
# 0    Avery Bradley  Boston Celtics       0       PG  25.0  06-Feb     180
# 1      Jae Crowder  Boston Celtics      99       SF   NaN  06-Jun     235
# 2     John Holland  Boston Celtics      30       SG  27.0  06-May     205
# 3      R.J. Hunter  Boston Celtics      28       SG  22.0  06-May     185
# 4    Jonas Jerebko  Boston Celtics       8       PF  29.0  06-Oct     231
# ..             ...             ...     ...      ...   ...     ...     ...
# 452     Trey Lyles       Utah Jazz      41       PF  20.0  06-Oct     234
# 453   Shelvin Mack       Utah Jazz       8       PG  26.0  06-Mar     203
# 454      Raul Neto       Utah Jazz      25       PG  24.0  06-Jan     179
# 455   Tibor Pleiss       Utah Jazz      21        C  26.0  07-Mar     256
# 456    Jeff Withey       Utah Jazz      24        C  26.0     7-0     231
#
#                College     Salary
# 0                Texas  7730337.0
# ...

# %%
google=pd.read_csv("google.csv",squeeze=True)
google1=google.head(n=len(nba))

# %%
nba["Price"]=google1

# %%
nba
# Out:
#               Name            Team  Number Position   Age  Height  Weight  \
# 0    Avery Bradley  Boston Celtics       0       PG  25.0  06-Feb     180
# 1      Jae Crowder  Boston Celtics      99       SF   NaN  06-Jun     235
# 2     John Holland  Boston Celtics      30       SG  27.0  06-May     205
# 3      R.J. Hunter  Boston Celtics      28       SG  22.0  06-May     185
# 4    Jonas Jerebko  Boston Celtics       8       PF  29.0  06-Oct     231
# ..             ...             ...     ...      ...   ...     ...     ...
# 452     Trey Lyles       Utah Jazz      41       PF  20.0  06-Oct     234
# 453   Shelvin Mack       Utah Jazz       8       PG  26.0  06-Mar     203
# 454      Raul Neto       Utah Jazz      25       PG  24.0  06-Jan     179
# 455   Tibor Pleiss       Utah Jazz      21        C  26.0  07-Mar     256
# 456    Jeff Withey       Utah Jazz      24        C  26.0     7-0     231
#
#                College     Salary   Price
# ...

# %%
len(nba)
# Out:
# 457

# %%
nba.insert( loc=2, column="Sports", value="Tennis" , allow_duplicates=True)
nba
# Out:
#               Name            Team  Sports  Sports  Sports  Number Position  \
# 0    Avery Bradley  Boston Celtics  Tennis  Tennis  Tennis       0       PG
# 1      Jae Crowder  Boston Celtics  Tennis  Tennis  Tennis      99       SF
# 2     John Holland  Boston Celtics  Tennis  Tennis  Tennis      30       SG
# 3      R.J. Hunter  Boston Celtics  Tennis  Tennis  Tennis      28       SG
# 4    Jonas Jerebko  Boston Celtics  Tennis  Tennis  Tennis       8       PF
# ..             ...             ...     ...     ...     ...     ...      ...
# 452     Trey Lyles       Utah Jazz  Tennis  Tennis  Tennis      41       PF
# 453   Shelvin Mack       Utah Jazz  Tennis  Tennis  Tennis       8       PG
# 454      Raul Neto       Utah Jazz  Tennis  Tennis  Tennis      25       PG
# 455   Tibor Pleiss       Utah Jazz  Tennis  Tennis  Tennis      21        C
# 456    Jeff Withey       Utah Jazz  Tennis  Tennis  Tennis      24        C
#
# ...

# %%
nba=pd.read_csv("nba.csv")
nba
# Out:
#               Name            Team  Number Position   Age  Height  Weight  \
# 0    Avery Bradley  Boston Celtics       0       PG  25.0  06-Feb     180
# 1      Jae Crowder  Boston Celtics      99       SF   NaN  06-Jun     235
# 2     John Holland  Boston Celtics      30       SG  27.0  06-May     205
# 3      R.J. Hunter  Boston Celtics      28       SG  22.0  06-May     185
# 4    Jonas Jerebko  Boston Celtics       8       PF  29.0  06-Oct     231
# ..             ...             ...     ...      ...   ...     ...     ...
# 452     Trey Lyles       Utah Jazz      41       PF  20.0  06-Oct     234
# 453   Shelvin Mack       Utah Jazz       8       PG  26.0  06-Mar     203
# 454      Raul Neto       Utah Jazz      25       PG  24.0  06-Jan     179
# 455   Tibor Pleiss       Utah Jazz      21        C  26.0  07-Mar     256
# 456    Jeff Withey       Utah Jazz      24        C  26.0     7-0     231
#
#                College     Salary
# 0                Texas  7730337.0
# ...

# %%
google_df=pd.read_csv("google.csv").head(len(nba)+10)
google_Series=pd.read_csv("google.csv", squeeze=True).head(len(nba))

# %%
print(google_df.shape)
google_df
# Out:
# (467, 1)
#      Stock Price
# 0          50.12
# 1          54.10
# 2          54.65
# 3          52.38
# 4          52.95
# ..           ...
# 462       193.39
# 463       200.86
# 464       199.78
# 465       202.23
# 466       201.91
#
# [467 rows x 1 columns]

# %%
print(google_Series.shape)
google_Series
# Out:
# (457,)
# 0       50.12
# 1       54.10
# 2       54.65
# 3       52.38
# 4       52.95
#         ...
# 452    194.80
# 453    193.06
# 454    196.45
# 455    193.09
# 456    190.58
# Name: Stock Price, Length: 457, dtype: float64

# %%
nba["Trial"]=google_Series

# %%
nba
# Out:
#               Name            Team  Number Position  Age  Height  Weight  \
# 0    Avery Bradley  Boston Celtics       0       PG    0  06-Feb     180
# 1      Jae Crowder  Boston Celtics      99       SF    0  06-Jun     235
# 2     John Holland  Boston Celtics      30       SG    0  06-May     205
# 3      R.J. Hunter  Boston Celtics      28       SG    0  06-May     185
# 4    Jonas Jerebko  Boston Celtics       8       PF    0  06-Oct     231
# ..             ...             ...     ...      ...  ...     ...     ...
# 452     Trey Lyles       Utah Jazz      41       PF    0  06-Oct     234
# 453   Shelvin Mack       Utah Jazz       8       PG    0  06-Mar     203
# 454      Raul Neto       Utah Jazz      25       PG    0  06-Jan     179
# 455   Tibor Pleiss       Utah Jazz      21        C    0  07-Mar     256
# 456    Jeff Withey       Utah Jazz      24        C    0     7-0     231
#
#                College     Salary   Trial  Trial 1
# ...

# %%
nba["Trial 1"]=google_df

# %%
nba
# Out:
#               Name            Team  Number Position  Age  Height  Weight  \
# 0    Avery Bradley  Boston Celtics       0       PG    0  06-Feb     180
# 1      Jae Crowder  Boston Celtics      99       SF    0  06-Jun     235
# 2     John Holland  Boston Celtics      30       SG    0  06-May     205
# 3      R.J. Hunter  Boston Celtics      28       SG    0  06-May     185
# 4    Jonas Jerebko  Boston Celtics       8       PF    0  06-Oct     231
# ..             ...             ...     ...      ...  ...     ...     ...
# 452     Trey Lyles       Utah Jazz      41       PF    0  06-Oct     234
# 453   Shelvin Mack       Utah Jazz       8       PG    0  06-Mar     203
# 454      Raul Neto       Utah Jazz      25       PG    0  06-Jan     179
# 455   Tibor Pleiss       Utah Jazz      21        C    0  07-Mar     256
# 456    Jeff Withey       Utah Jazz      24        C    0     7-0     231
#
#                College     Salary   Trial  Trial 1
# ...

# %%
n=nba["Trial"].sort_values(ascending=False)

# %%
nba
# Out:
#               Name            Team  Number Position  Age  Height  Weight  \
# 0    Avery Bradley  Boston Celtics       0       PG    0  06-Feb     180
# 1      Jae Crowder  Boston Celtics      99       SF    0  06-Jun     235
# 2     John Holland  Boston Celtics      30       SG    0  06-May     205
# 3      R.J. Hunter  Boston Celtics      28       SG    0  06-May     185
# 4    Jonas Jerebko  Boston Celtics       8       PF    0  06-Oct     231
# ..             ...             ...     ...      ...  ...     ...     ...
# 452     Trey Lyles       Utah Jazz      41       PF    0  06-Oct     234
# 453   Shelvin Mack       Utah Jazz       8       PG    0  06-Mar     203
# 454      Raul Neto       Utah Jazz      25       PG    0  06-Jan     179
# 455   Tibor Pleiss       Utah Jazz      21        C    0  07-Mar     256
# 456    Jeff Withey       Utah Jazz      24        C    0     7-0     231
#
#                College     Salary   Trial  Trial 1
# ...

# %%
a=2
x=a
y=a
a=3
print(x,y,sep="  ")
# Out:
# 2  2

# %%
nba["Age"]=0
nba
# Out:
#               Name            Team  Number Position  Age  Height  Weight  \
# 0    Avery Bradley  Boston Celtics       0       PG    0  06-Feb     180
# 1      Jae Crowder  Boston Celtics      99       SF    0  06-Jun     235
# 2     John Holland  Boston Celtics      30       SG    0  06-May     205
# 3      R.J. Hunter  Boston Celtics      28       SG    0  06-May     185
# 4    Jonas Jerebko  Boston Celtics       8       PF    0  06-Oct     231
# ..             ...             ...     ...      ...  ...     ...     ...
# 452     Trey Lyles       Utah Jazz      41       PF    0  06-Oct     234
# 453   Shelvin Mack       Utah Jazz       8       PG    0  06-Mar     203
# 454      Raul Neto       Utah Jazz      25       PG    0  06-Jan     179
# 455   Tibor Pleiss       Utah Jazz      21        C    0  07-Mar     256
# 456    Jeff Withey       Utah Jazz      24        C    0     7-0     231
#
#                College     Salary   Trial  Trial 1
# ...

# %%
array=np.arange(100)

# %%
arr_series=pd.Series(array)
arr_series
# Out:
# 0      0
# 1      1
# 2      2
# 3      3
# 4      4
#       ..
# 95    95
# 96    96
# 97    97
# 98    98
# 99    99
# Length: 100, dtype: int32

# %%
nba["New1"]=arr_series
nba
# Out:
#               Name            Team  Number Position  Age  Height  Weight  \
# 0    Avery Bradley  Boston Celtics       0       PG    0  06-Feb     180
# 1      Jae Crowder  Boston Celtics      99       SF    0  06-Jun     235
# 2     John Holland  Boston Celtics      30       SG    0  06-May     205
# 3      R.J. Hunter  Boston Celtics      28       SG    0  06-May     185
# 4    Jonas Jerebko  Boston Celtics       8       PF    0  06-Oct     231
# ..             ...             ...     ...      ...  ...     ...     ...
# 452     Trey Lyles       Utah Jazz      41       PF    0  06-Oct     234
# 453   Shelvin Mack       Utah Jazz       8       PG    0  06-Mar     203
# 454      Raul Neto       Utah Jazz      25       PG    0  06-Jan     179
# 455   Tibor Pleiss       Utah Jazz      21        C    0  07-Mar     256
# 456    Jeff Withey       Utah Jazz      24        C    0     7-0     231
#
#                College     Salary   Trial  Trial 1  New  New1
# ...

# %%
nba.dropna(how="any")
# Out:
#                         Name                  Team  Number Position  Age  \
# 0              Avery Bradley        Boston Celtics       0       PG    0
# 1                Jae Crowder        Boston Celtics      99       SF    0
# 3                R.J. Hunter        Boston Celtics      28       SG    0
# 6              Jordan Mickey        Boston Celtics      55       PF    0
# 7               Kelly Olynyk        Boston Celtics      41        C    0
# ..                       ...                   ...     ...      ...  ...
# 95                Jeff Green  Los Angeles Clippers       8       SF    0
# 96             Blake Griffin  Los Angeles Clippers      32       PF    0
# 97            Wesley Johnson  Los Angeles Clippers      33       SF    0
# 98            DeAndre Jordan  Los Angeles Clippers       6        C    0
# 99  Luc Richard Mbah a Moute  Los Angeles Clippers      12       PF    0
#
#     Height  Weight        College      Salary  Trial  Trial 1  New  New1
# ...

# %%
nba.insert(loc=2, column="insert column" , value=google , allow_duplicates= False)

# %%
nba
# Out:
#               Name            Team  insert column  Number Position  Age  \
# 0    Avery Bradley  Boston Celtics          50.12       0       PG    0
# 1      Jae Crowder  Boston Celtics          54.10      99       SF    0
# 2     John Holland  Boston Celtics          54.65      30       SG    0
# 3      R.J. Hunter  Boston Celtics          52.38      28       SG    0
# 4    Jonas Jerebko  Boston Celtics          52.95       8       PF    0
# ..             ...             ...            ...     ...      ...  ...
# 452     Trey Lyles       Utah Jazz         194.80      41       PF    0
# 453   Shelvin Mack       Utah Jazz         193.06       8       PG    0
# 454      Raul Neto       Utah Jazz         196.45      25       PG    0
# 455   Tibor Pleiss       Utah Jazz         193.09      21        C    0
# 456    Jeff Withey       Utah Jazz         190.58      24        C    0
#
#      Height  Weight            College     Salary   Trial  Trial 1  New  New1
# ...

# %%
nba=pd.read_csv("nba.csv")

# %%
nba
# Out:
#               Name            Team  Number Position   Age  Height  Weight  \
# 0    Avery Bradley  Boston Celtics       0       PG  25.0  06-Feb     180
# 1      Jae Crowder  Boston Celtics      99       SF   NaN  06-Jun     235
# 2     John Holland  Boston Celtics      30       SG  27.0  06-May     205
# 3      R.J. Hunter  Boston Celtics      28       SG  22.0  06-May     185
# 4    Jonas Jerebko  Boston Celtics       8       PF  29.0  06-Oct     231
# ..             ...             ...     ...      ...   ...     ...     ...
# 452     Trey Lyles       Utah Jazz      41       PF  20.0  06-Oct     234
# 453   Shelvin Mack       Utah Jazz       8       PG  26.0  06-Mar     203
# 454      Raul Neto       Utah Jazz      25       PG  24.0  06-Jan     179
# 455   Tibor Pleiss       Utah Jazz      21        C  26.0  07-Mar     256
# 456    Jeff Withey       Utah Jazz      24        C  26.0     7-0     231
#
#                College     Salary
# 0                Texas  7730337.0
# ...

# %%
s1=pd.Series(nba["Weight"]).sort_values()
print(s1)
# Out:
# 152    161
# 350    165
# 263    165
# 359    169
# 286    170
#       ...
# 188    279
# 395    280
# 330    289
# 302    290
# 405    307
# Name: Weight, Length: 457, dtype: int64

# %%
nba["Weight"]=s1
nba
# Out:
#               Name            Team  Number Position   Age  Height  Weight  \
# 0    Avery Bradley  Boston Celtics       0       PG  25.0  06-Feb     180
# 1      Jae Crowder  Boston Celtics      99       SF   NaN  06-Jun     235
# 2     John Holland  Boston Celtics      30       SG  27.0  06-May     205
# 3      R.J. Hunter  Boston Celtics      28       SG  22.0  06-May     185
# 4    Jonas Jerebko  Boston Celtics       8       PF  29.0  06-Oct     231
# ..             ...             ...     ...      ...   ...     ...     ...
# 452     Trey Lyles       Utah Jazz      41       PF  20.0  06-Oct     234
# 453   Shelvin Mack       Utah Jazz       8       PG  26.0  06-Mar     203
# 454      Raul Neto       Utah Jazz      25       PG  24.0  06-Jan     179
# 455   Tibor Pleiss       Utah Jazz      21        C  26.0  07-Mar     256
# 456    Jeff Withey       Utah Jazz      24        C  26.0     7-0     231
#
#                College     Salary
# 0                Texas  7730337.0
# ...

# %%
nba=pd.read_csv("nba.csv")

# %%
nba.dropna(inplace=True ,how="all")
nba
# Out:
#               Name            Team  Number Position   Age  Height  Weight  \
# 0    Avery Bradley  Boston Celtics       0       PG  25.0  06-Feb     180
# 1      Jae Crowder  Boston Celtics      99       SF   NaN  06-Jun     235
# 2     John Holland  Boston Celtics      30       SG  27.0  06-May     205
# 3      R.J. Hunter  Boston Celtics      28       SG  22.0  06-May     185
# 4    Jonas Jerebko  Boston Celtics       8       PF  29.0  06-Oct     231
# ..             ...             ...     ...      ...   ...     ...     ...
# 452     Trey Lyles       Utah Jazz      41       PF  20.0  06-Oct     234
# 453   Shelvin Mack       Utah Jazz       8       PG  26.0  06-Mar     203
# 454      Raul Neto       Utah Jazz      25       PG  24.0  06-Jan     179
# 455   Tibor Pleiss       Utah Jazz      21        C  26.0  07-Mar     256
# 456    Jeff Withey       Utah Jazz      24        C  26.0     7-0     231
#
#                College     Salary
# 0                Texas  7730337.0
# ...

# %%
nba[ ["Weight"] ].sort_values("Weight")
# Out:
#      Weight
# 152     161
# 350     165
# 263     165
# 359     169
# 286     170
# ..      ...
# 188     279
# 395     280
# 330     289
# 302     290
# 405     307
#
# [457 rows x 1 columns]

# %%
nba["Weight"].rank()
